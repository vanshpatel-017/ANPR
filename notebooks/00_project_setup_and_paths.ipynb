# %% [markdown]
# # 00 — Environment, Paths, and Run Contracts
#
# Define runtime checks and path contracts consumed by all downstream notebooks.

# %%
import os
import platform
import sys
from pathlib import Path

print('Python   :', sys.version.split()[0])
print('Exec path:', sys.executable)
print('Platform :', platform.platform())

# %%
import torch

print('Torch version:', torch.__version__)
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))

# %%
DATA_ROOT = Path(os.getenv('ANPR_DATA_ROOT', 'C:/path/to/private/data'))
MODEL_ROOT = Path(os.getenv('ANPR_MODEL_ROOT', 'C:/path/to/private/models'))

PATHS = {
    'raw_source': DATA_ROOT / 'raw',
    'dataset_recreated': DATA_ROOT / 'DATASET',
    'dataset_final': DATA_ROOT / 'FINAL_DATASET',
    'bootstrap_root': DATA_ROOT / 'Bootstrap_5k',
    'ocr_dataset_root': DATA_ROOT / 'OCR_Dataset',
    'runs': DATA_ROOT / 'runs',
    'models': MODEL_ROOT
}

for k, v in PATHS.items():
    print(f'{k:20s} -> {v}')
